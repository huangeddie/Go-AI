# %%
import MCST

# %% [markdown]
# # Tree

# %%
def foo():
    return ALPHA

# %%
MCST.test(foo)
# Out:
# 1

# %%
ALPHA = 1

# %%
import tensorflow as tf

# %%
A = tf.Tensor([[1,2],[3,4]])
A[(0,1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b5ff378ee98c> in <module>
# ----> 1 A = tf.Tensor([[1,2],[3,4]])
#       2 A[(0,1)]
#
# TypeError: __init__() missing 2 required positional arguments: 'value_index' and 'dtype'
